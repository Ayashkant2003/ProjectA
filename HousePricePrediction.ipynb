# %%
# Importing the required libraries

import numpy as np
import pandas as pd

# Libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\ayash\\Desktop\\ProJect'

# %%
df=pd.read_csv('House_Price.csv')

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
# n_hos_beds has missing Data

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
# crime_rate, n_hot_rooms, rainfall may have outliers

# %% [markdown]
# ## Data Visualization

# %%
sns.jointplot(x='crime_rate',y='price',data=df,color='purple')

# %%
sns.distplot(df['crime_rate'],color='red')
# Out:
# <AxesSubplot:xlabel='crime_rate', ylabel='Density'>

# %%
sns.jointplot(x='n_hot_rooms',y='price',data=df,color='green')

# %%
sns.jointplot(x='rainfall',y='price',data=df,color='blue')

# %%
sns.countplot(x='airport',data=df,palette='inferno')
# Out:
# <AxesSubplot:xlabel='airport', ylabel='count'>

# %%
sns.countplot(x='waterbody',data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='waterbody', ylabel='count'>

# %%
sns.countplot(x='bus_ter',data=df,palette='Pastel1_r')
# Out:
# <AxesSubplot:xlabel='bus_ter', ylabel='count'>

# %%
# bus_ter has only yes values

# %% [markdown]
# ## Observations
#
# ### 1. n_hos_beds column has missing values
# ### 2. Distribution of crime_rate is right skewed
# ### 3. n_hot_rooms column has 2 outliers
# ### 4. rainfall column has 1 outlier
# ### 5. bus_ter column has only YES values

# %%
# Filling the missing data

df['n_hos_beds'] = df['n_hos_beds'].fillna(df['n_hos_beds'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   506 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
# Reducing the skewness of crime_rate data


df['crime_rate']=np.log(1+df['crime_rate'])

# %%
sns.scatterplot(x='crime_rate',y='price',data=df,color='red')
# Out:
# <AxesSubplot:xlabel='crime_rate', ylabel='price'>

# %%
# Treating the outliers of n_hot_rooms

# Inter Quartile Range

Q1 = df['n_hot_rooms'].quantile(0.25)
Q3 = df['n_hot_rooms'].quantile(0.75)

IQR =Q3-Q1

upper_bound = Q3+1.5*IQR

# %%
df[df['n_hot_rooms']>upper_bound]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7    0.026924       37.07     0.469     7.185  61.1   5.03   4.86
# 423   13.4    2.085724       48.10     0.614     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 423   2.34   1.87      19.8      23.29      NO       8.268        81.12
#
#     waterbody  rainfall bus_ter     parks
# 2        None        38     YES  0.045764
# 423      Lake        29     YES  0.063344

# %%
df.loc[df['n_hot_rooms'] > upper_bound, 'n_hot_rooms'] = upper_bound

# %%
sns.jointplot(x='n_hot_rooms',y='price',data=df,color='orange')

# %%
# Treating outlier of rainfall columns

lv=np.percentile(df.rainfall,1)
lv
# Out:
# 20.0

# %%
df.loc[df['rainfall']<0.5*lv,'rainfall']=0.5*lv

# %%
sns.scatterplot(x='rainfall',y='price',data=df,color='blue')
# Out:
# <AxesSubplot:xlabel='rainfall', ylabel='price'>

# %%
# Dropping the bus_ter column

df=df.drop('bus_ter',axis=1)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394      18.6423
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall     parks
# 0     River        23  0.049347
# 1      Lake        42  0.046146
# ...

# %%
df['avg_dist']=(df.dist1+df.dist2+df.dist3+df.dist4)/4

# %%
df=df.drop(['dist1','dist2','dist3','dist4'],axis=1)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall     parks  \
# 0       4.98     YES       5.480      11.1920     River        23  0.049347
# 1       9.14      NO       7.332      12.1728      Lake        42  0.046146
# 2       4.03      NO       7.394      18.6423      None        38  0.045764
# 3       2.94     YES       9.268      11.2672      Lake        45  0.047151
# 4       5.33      NO       8.824      11.2896      Lake        55  0.039474
#
#    avg_dist
# 0    4.0875
# 1    4.9675
# 2    4.9675
# 3    6.0650
# 4    6.0625

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  506.000000  506.000000  506.000000   506.000000  506.000000
# mean    21.544466   12.653063    7.899767    12.755132   39.195652
# ...

# %%
# Creating dummy variables for categorical data

df=pd.get_dummies(df)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480      11.1920        23  0.049347    4.0875
# 1       9.14       7.332      12.1728        42  0.046146    4.9675
# 2       4.03       7.394      18.6423        38  0.045764    4.9675
# 3       2.94       9.268      11.2672        45  0.047151    6.0650
# 4       5.33       8.824      11.2896        55  0.039474    6.0625
#
#    airport_NO  airport_YES  waterbody_Lake  waterbody_Lake and River  \
# ...

# %%
del df['airport_NO']
del df['waterbody_None']

# %%
# Analyzing Correlation among variables
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),cmap='viridis',annot=True)
# Out:
# <AxesSubplot:>

# %%
# Since air_qual and parks are highly correlated; we can drop parks column to avoid multicolinearity
del df['parks']

# %% [markdown]
# ## Implementing Neural Networks for price prediction

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
X=df.drop('price',axis=1).values

# %%
y=df['price'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Scaling the data 

scaler=MinMaxScaler()

X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (354, 15)

# %%
#Creating the model

model=Sequential()


model.add(Dense(15,activation='relu'))
model.add(Dense(15,activation='relu'))
model.add(Dense(15,activation='relu'))
model.add(Dense(15,activation='relu'))
model.add(Dense(1,activation='relu'))

model.compile(loss='mse',optimizer='adam')

# %%
# Fitting the Data

model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 614.8804 - val_loss: 530.8693
# Epoch 2/400
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 604.1708 - val_loss: 529.8762
# Epoch 3/400
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 629.6053 - val_loss: 528.6611
# Epoch 4/400
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 626.9720 - val_loss: 527.3000
# Epoch 5/400
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 631.9200 - val_loss: 525.9332
# Epoch 6/400
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 595.0234 - val_loss: 524.5525
# Epoch 7/400
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 597.7485 - val_loss: 523.1016
# Epoch 8/400
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 595.6938 - val_loss: 521.5323
# Epoch 9/400
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 611.6932 - val_loss: 519.8152
# Epoch 10/400
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 618.7567 - val_loss: 517.9390
# Epoch 11/400
# ...

# %%
losses=pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %%
# Evaluationg the model

pred=model.predict(X_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
print('MAE:', mean_absolute_error(y_test, pred))  
print('MSE:', mean_squared_error(y_test, pred))  
print('RMSE:', np.sqrt(mean_squared_error(y_test, pred)))
print('VarScore:', explained_variance_score(y_test, pred))
# Out:
# MAE: 2.9286850678293326
# MSE: 17.720575901955964
# RMSE: 4.209581440233217
# VarScore: 0.7633203144675984

# %%
df['price'].describe()
# Out:
# count    506.000000
# mean      22.528854
# std        9.182176
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: price, dtype: float64

# %%
residuals = (y_test-pred)
sns.distplot(residuals,color='green')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
singlehouse=df.drop('price',axis=1).iloc[99].values

# %%
singlehouse=scaler.transform(singlehouse.reshape(-1,15))

# %%
model.predict(singlehouse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# array([[32.823444]], dtype=float32)

# %%
df.iloc[99]['price']
# Out:
# 33.2

# %% [markdown]
# # Thank You!
